# %% [markdown]
# ## Week 1 Project: A Comparative Analysis of Noise Pollution Across Major Indian Cities (2019-2020)

# %% [markdown]
# Step 1: Import Necessary Libraries

# %%
import pandas as pd
import numpy as np

# Set pandas to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# Step 2: Load the Dataset

# %%
try:
    df = pd.read_csv('RS_Session_255_AU_1338_3.csv')
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: 'RS_Session_255_AU_1338_3.csv' not found. Please ensure the dataset file is in the correct folder.")
# Out:
# Dataset loaded successfully!

# %% [markdown]
# Step 3: Perform Initial Exploration

# %%
# Display the first 5 rows to get a feel for the data
print("--- First 5 Rows of the Dataset ---")
display(df.head())
# Out:
# --- First 5 Rows of the Dataset ---
#    Sl.No. Stations Name with Zone - City Stations Name with Zone - Location  \
# 0       1                      Bengaluru                  ParisarBhawan (C)
# 1       2                      Bengaluru                        Peeniya (I)
# 2       3                      Bengaluru                  NisargaBhawan (R)
# 3       4                      Bengaluru                      Marathali (C)
# 4       5                      Bengaluru                            BTM (R)
#
#    Limit in dB(A) Leq - Day - 06 AM to 10PM  \
# 0                                        65
# 1                                        75
# 2                                        55
# 3                                        65
# 4                                        55
#
#    Limit in dB(A) Leq - Night - 10PM to 06AM  2019 - Day - Leq. dB(A)  \
# 0                                         55                     67.2
# ...

# %% [markdown]
# Get Dataset Information

# %%
# Get a concise summary of the dataframe
print("\n\n--- Dataset Info ---")
df.info()
print("\n\n--- Dataset Description ---")
display(df.describe())
# Out:
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Sl.No.                                     70 non-null     int64
#  1   Stations Name with Zone - City             70 non-null     object
#  2   Stations Name with Zone - Location         70 non-null     object
#  3   Limit in dB(A) Leq - Day - 06 AM to 10PM   70 non-null     int64
#  4   Limit in dB(A) Leq - Night - 10PM to 06AM  70 non-null     int64
#  5   2019 - Day - Leq. dB(A)                    70 non-null     float64
#  6   2019 - Night - Leq. dB(A)                  70 non-null     float64
#  7   2020 - Day - Leq. dB(A)                    70 non-null     float64
#  8   2020 - Night - Leq. dB(A)                  70 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 5.1+ KB
# ...

# %% [markdown]
# Check for Missing Values

# %%
# Check for missing values in each column
print("\n\n--- Missing Values Check ---")
print(df.isnull().sum())
# Out:
# --- Missing Values Check ---
# Sl.No.                                       0
# Stations Name with Zone - City               0
# Stations Name with Zone - Location           0
# Limit in dB(A) Leq - Day - 06 AM to 10PM     0
# Limit in dB(A) Leq - Night - 10PM to 06AM    0
# 2019 - Day - Leq. dB(A)                      0
# 2019 - Night - Leq. dB(A)                    0
# 2020 - Day - Leq. dB(A)                      0
# 2020 - Night - Leq. dB(A)                    0
# dtype: int64
